# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ### 1. 재개발 횟수(원 크기)와 중앙값 거래가(색상도) 비교 분석

# %%
import pandas as pd
import folium
import numpy as np
import matplotlib.colors as colors
import matplotlib.cm as cm

# 1. 부동산 실거래가 데이터 처리 및 동-구 매핑 사전 생성
df_price = pd.read_csv('서울시 부동산 실거래가 정보(2022~2025).csv', encoding='cp949', low_memory=False)

# 동 이름 -> 구 이름 매핑 사전 (예: {"소공동": "중구", "공덕동": "마포구" ...})
# 실거래가 데이터에 법정동과 자치구 활용
dong_to_gu = df_price[['법정동명', '자치구명']].drop_duplicates().set_index('법정동명')['자치구명'].to_dict()

# 가격 데이터 중앙값 계산
df_price['물건금액(만원)'] = pd.to_numeric(df_price['물건금액(만원)'], errors='coerce')
price_stats = df_price.groupby('자치구명')['물건금액(만원)'].median().reset_index()
price_stats.columns = ['자치구명', '가격중앙값']

# 2. 정비사업 데이터 처리
df_plan = pd.read_csv("서울시 도시계획 정비사업 현황.csv", encoding="cp949")
df_plan["일자"] = df_plan["프로젝트코드"].str[8:16]
df_plan["구명"] = ""

for i in range(len(df_plan)):
    location_val = df_plan.loc[i, "위치명"]
    if pd.notnull(location_val) and str(location_val).strip() != "":
        loc_str = str(location_val).replace("서울특별시", "").replace("서울시", "").strip()
        
        #주소에서 '동'이나 '로' 이름을 추출하여 구명으로 변환, 구가 없는 결측치 데이터 보완
        find_idx = loc_str.find(" ")
        if find_idx == -1: find_idx = loc_str.find("동")
        if find_idx == -1: find_idx = loc_str.find("로")
        
        # 띄어쓰기나 '동/로' 앞의 글자 추출
        extracted_name = loc_str[:find_idx+1].strip() if find_idx != -1 else loc_str
        
        # 추출된 이름이 구라면 그대로 쓰고, 
        # 동 이름이라면 사전에서 구 이름을 찾아 사용.
        if "구" in extracted_name and len(extracted_name) <= 4:
            target_gu = extracted_name
        else:
            target_gu = dong_to_gu.get(extracted_name, "기타")
            
        df_plan.at[i, "구명"] = target_gu
    else:
        df_plan.at[i, "구명"] = "NULL"

# 2022년 이후 & 재개발 필터링, 소분류가 재개발이 아닌 행은 사용 안함.
redev_df = df_plan[(df_plan["일자"] >= "20220101") & (df_plan["소분류"].str.contains("재개발", na=False))].copy()

# 정상 집계
redev_counts = redev_df["구명"].value_counts().reset_index()
redev_counts.columns = ["자치구명", "재개발건수"]

# 3. 데이터 병합
final_map_df = pd.merge(redev_counts, price_stats, on="자치구명")

# 4. 지도 시각화
seoul_geo = {
    '강남구': [37.495, 127.062], '강동구': [37.549, 127.146], '강북구': [37.642, 127.011],
    '강서구': [37.561, 126.825], '관악구': [37.465, 126.943], '광진구': [37.546, 127.085],
    '구로구': [37.494, 126.856], '금천구': [37.460, 126.900], '노원구': [37.652, 127.075],
    '도봉구': [37.669, 127.032], '동대문구': [37.581, 127.054], '동작구': [37.502, 126.951],
    '마포구': [37.559, 126.908], '서대문구': [37.577, 126.939], '서초구': [37.473, 127.031],
    '성동구': [37.551, 127.041], '성북구': [37.605, 127.017], '송파구': [37.505, 127.115],
    '양천구': [37.524, 126.855], '영등포구': [37.522, 126.910], '용산구': [37.530, 126.980],
    '은평구': [37.619, 126.927], '종로구': [37.594, 126.977], '중구': [37.560, 126.995], '중랑구': [37.597, 127.092]
}

m = folium.Map(location=[37.563, 126.986], zoom_start=11, tiles='cartodbpositron')
norm = colors.Normalize(vmin=final_map_df['가격중앙값'].min(), vmax=final_map_df['가격중앙값'].max())
colormap = cm.get_cmap('YlOrRd')

for _, row in final_map_df.iterrows():
    gu = row['자치구명']
    if gu in seoul_geo:
        color_hex = colors.to_hex(colormap(norm(row['가격중앙값'])))
        radius_val = np.sqrt(row['재개발건수']) * 6 + 5 
        
        folium.CircleMarker(
            location=seoul_geo[gu],
            radius=radius_val,
            color=color_hex,
            fill=True,
            fill_color=color_hex,
            fill_opacity=0.7,
            popup=f"<b>{gu}</b><br>재개발: {row['재개발건수']}건<br>중앙값: {row['가격중앙값']:.0f}만원",
        ).add_to(m)
        
        folium.Marker(
            location=seoul_geo[gu],
            icon=folium.DivIcon(html=f'<div style="font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;">{gu}</div>')
        ).add_to(m)

m.save('seoul_redevelopment_complete_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eafd62cac61bae7393b7e75ce639cdca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eafd62cac61bae7393b7e75ce639cdca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eafd62cac61bae7393b7e75ce639cdca = L.map(
#                 &quot;map_eafd62cac61bae7393b7e75ce639cdca&quot;,
#                 {
#                     center: [37.563, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7fc0b44fece48e330d57c06e8e80460 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7fc0b44fece48e330d57c06e8e80460.addTo(map_eafd62cac61bae7393b7e75ce639cdca);
#
#
#             var circle_marker_7bcd35f732418eee17dd40ad39eb329f = L.circleMarker(
#                 [37.605, 127.017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fea546&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fea546&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 31.153393661244046, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_eafd62cac61bae7393b7e75ce639cdca);
#
#
#         var popup_a8d8d70e7df5bda1475327b2cb02b29d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7162317fd87781276eb369055b8a95a7 = $(`&lt;div id=&quot;html_7162317fd87781276eb369055b8a95a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;성북구&lt;/b&gt;&lt;br&gt;재개발: 19건&lt;br&gt;중앙값: 63000만원&lt;/div&gt;`)[0];
#                 popup_a8d8d70e7df5bda1475327b2cb02b29d.setContent(html_7162317fd87781276eb369055b8a95a7);
#
#
#
#         circle_marker_7bcd35f732418eee17dd40ad39eb329f.bindPopup(popup_a8d8d70e7df5bda1475327b2cb02b29d)
#         ;
#
#
#
#
#             var marker_569e6bdfe2e4200a9ef239896569c71a = L.marker(
#                 [37.605, 127.017],
#                 {
# }
#             ).addTo(map_eafd62cac61bae7393b7e75ce639cdca);
#
#
#             var div_icon_f4d41fae920d3c2ed645e7ad2a95573c = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;\&quot;\u003e\uc131\ubd81\uad6c\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_569e6bdfe2e4200a9ef239896569c71a.setIcon(div_icon_f4d41fae920d3c2ed645e7ad2a95573c);
#
#
#             var circle_marker_61d490998d65980aa201d9624ed62c08 = L.circleMarker(
#                 [37.581, 127.054],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#feb953&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#feb953&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 29.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_eafd62cac61bae7393b7e75ce639cdca);
#
#
#         var popup_25a6da0748289ac67eeb53ea4f949f47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a4261ee4d75378d992fcd7ee9ed8f98 = $(`&lt;div id=&quot;html_5a4261ee4d75378d992fcd7ee9ed8f98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;동대문구&lt;/b&gt;&lt;br&gt;재개발: 16건&lt;br&gt;중앙값: 57425만원&lt;/div&gt;`)[0];
#                 popup_25a6da0748289ac67eeb53ea4f949f47.setContent(html_5a4261ee4d75378d992fcd7ee9ed8f98);
#
#
#
#         circle_marker_61d490998d65980aa201d9624ed62c08.bindPopup(popup_25a6da0748289ac67eeb53ea4f949f47)
#         ;
#
#
#
#
#             var marker_6ffcee92217d7dc27db36aa6f4b42a0e = L.marker(
#                 [37.581, 127.054],
#                 {
# }
#             ).addTo(map_eafd62cac61bae7393b7e75ce639cdca);
#
#
#             var div_icon_7c946409d581e643e015f8fb9539598a = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left:

# %% [markdown]
# ### 2. 재개발 횟수와 상위 25% 거래가 비교 분석

# %%
import pandas as pd
import folium
import numpy as np
import matplotlib.colors as colors
import matplotlib.cm as cm
import re

# 1. 데이터 로드
# 파일명이 실제 환경과 다를 수 있으니 확인 바랍니다.
price_temp = pd.read_csv("서울시 부동산 실거래가 정보(2022~2025).csv", encoding="cp949", low_memory=False)
df_plan = pd.read_csv("서울시 도시계획 정비사업 현황.csv", encoding="cp949")

# 2. 법정동-자치구 매핑 사전 생성 (동 이름만 있을 때를 대비)
# 중복된 동 이름(예: 신사동) 중 가장 빈도가 높은 구를 선택하여 매핑의 일관성 유지
mapping_df = price_temp[['법정동명', '자치구명']].value_counts().reset_index()
dong_to_gu = mapping_df.drop_duplicates('법정동명').set_index('법정동명')['자치구명'].to_dict()

# 서울시 자치구 리스트 (정확한 매칭용)
seoul_gu_list = [
    '강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', 
    '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', 
    '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'
]

# 3. 구명 추출 함수 (안정성 강화)
def get_gu_name(location_val):
    if pd.isnull(location_val) or str(location_val).strip() == "":
        return "NULL"
    
    loc_str = str(location_val).replace("서울특별시", "").replace("서울시", "").strip()
    
    # [Step 1] 문자열 내에 자치구 이름이 직접 포함되어 있는지 확인 (가장 확실한 방법)
    for gu in seoul_gu_list:
        if gu in loc_str:
            return gu
            
    # [Step 2] 주요 동/로 이름 예외 매핑
    special_cases = {
        "영등포동": "영등포구", "노량진동": "동작구", "신림동": "관악구", 
        "중곡동": "광진구", "전농동": "동대문구", "금호동": "성동구", 
        "길음동": "성북구", "상계동": "노원구", "수색": "은평구", "명륜": "종로구", "한강로": "용산구"
    }
    for key, val in special_cases.items():
        if key in loc_str:
            return val

    # [Step 3] 동 이름을 정규표현식으로 추출하여 사전 검색
    match = re.search(r'([가-힣]+(?:동|로|가))', loc_str)
    if match:
        dong_name = match.group(1)
        return dong_to_gu.get(dong_name, "기타")
        
    return "기타"

# 4. 정비사업 데이터 처리
df_plan["일자"] = df_plan["프로젝트코드"].str[8:16]
df_plan["구명"] = df_plan["위치명"].apply(get_gu_name)

# 2022년 이후 & '재개발' 필터링
redev_df = df_plan[(df_plan["일자"] >= "20220101") & (df_plan["소분류"].str.contains("재개발", na=False))].copy()
redev_counts = redev_df["구명"].value_counts().reset_index()
redev_counts.columns = ["자치구명", "재개발건수"]

# 5. 실거래가 데이터 처리 (2024년 이후 상위 25%)
price_recent = price_temp[price_temp['계약일'] >= 20240101].copy()
price_recent['단위면적당금액'] = price_recent['물건금액(만원)'] / price_recent['건물면적(㎡)']
price_stats = price_recent.groupby('자치구명')['단위면적당금액'].quantile(0.75).reset_index()
price_stats.columns = ['자치구명', '상위25%가격']

# 6. 데이터 병합 (how='left'를 사용하여 재개발 건수가 있는 구는 누락되지 않게 함)
final_df = pd.merge(redev_counts, price_stats, on="자치구명", how="left")
final_df = final_df[final_df['자치구명'] != "기타"].dropna(subset=['상위25%가격'])

# 7. 지도 시각화
seoul_geo = {
    '강남구': [37.495, 127.062], '강동구': [37.549, 127.146], '강북구': [37.642, 127.011],
    '강서구': [37.561, 126.825], '관악구': [37.465, 126.943], '광진구': [37.546, 127.085],
    '구로구': [37.494, 126.856], '금천구': [37.460, 126.900], '노원구': [37.652, 127.075],
    '도봉구': [37.669, 127.032], '동대문구': [37.581, 127.054], '동작구': [37.502, 126.951],
    '마포구': [37.559, 126.908], '서대문구': [37.577, 126.939], '서초구': [37.473, 127.031],
    '성동구': [37.551, 127.041], '성북구': [37.605, 127.017], '송파구': [37.505, 127.115],
    '양천구': [37.524, 126.855], '영등포구': [37.522, 126.910], '용산구': [37.530, 126.980],
    '은평구': [37.619, 126.927], '종로구': [37.594, 126.977], '중구': [37.560, 126.995], '중랑구': [37.597, 127.092]
}

m = folium.Map(location=[37.563, 126.986], zoom_start=11, tiles='cartodbpositron')
norm = colors.Normalize(vmin=final_df['상위25%가격'].min(), vmax=final_df['상위25%가격'].max())
cmap = cm.get_cmap('YlOrRd')

for _, row in final_df.iterrows():
    gu = row['자치구명']
    if gu in seoul_geo:
        color_hex = colors.to_hex(cmap(norm(row['상위25%가격'])))
        radius_val = row['재개발건수'] * 3 + 3 
        
        folium.CircleMarker(
            location=seoul_geo[gu],
            radius=radius_val,
            color=color_hex,
            fill=True,
            fill_color=color_hex,
            fill_opacity=0.7,
            popup=f"<b>{gu}</b><br>재개발(22-25): {int(row['재개발건수'])}건<br>상위 25% 평당가: {(row['상위25%가격']*3.3):.0f}만원",
        ).add_to(m)
        
        folium.Marker(
            location=seoul_geo[gu],
            icon=folium.DivIcon(html=f'<div style="font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;">{gu}</div>')
        ).add_to(m)

m.save('seoul_redevelopment_fixed_final.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9aa25e6801152f920971746e38660f52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9aa25e6801152f920971746e38660f52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9aa25e6801152f920971746e38660f52 = L.map(
#                 &quot;map_9aa25e6801152f920971746e38660f52&quot;,
#                 {
#                     center: [37.563, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_890c6d297b0243b2627b63dfe2471694 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_890c6d297b0243b2627b63dfe2471694.addTo(map_9aa25e6801152f920971746e38660f52);
#
#
#             var circle_marker_f472470cbee80f6cef71611cb98c99ad = L.circleMarker(
#                 [37.605, 127.017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fedc7c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fedc7c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 60, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9aa25e6801152f920971746e38660f52);
#
#
#         var popup_271de1cb6a06683392de1e8e29506a1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d22827e4d7700dc5460de7c7b630d49 = $(`&lt;div id=&quot;html_6d22827e4d7700dc5460de7c7b630d49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;성북구&lt;/b&gt;&lt;br&gt;재개발(22-25): 19건&lt;br&gt;상위 25% 평당가: 3966만원&lt;/div&gt;`)[0];
#                 popup_271de1cb6a06683392de1e8e29506a1b.setContent(html_6d22827e4d7700dc5460de7c7b630d49);
#
#
#
#         circle_marker_f472470cbee80f6cef71611cb98c99ad.bindPopup(popup_271de1cb6a06683392de1e8e29506a1b)
#         ;
#
#
#
#
#             var marker_6d22eca3a2fa68a73d60fce62b1ed134 = L.marker(
#                 [37.605, 127.017],
#                 {
# }
#             ).addTo(map_9aa25e6801152f920971746e38660f52);
#
#
#             var div_icon_0476ef10f6fc455d2c28fce366441c85 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;\&quot;\u003e\uc131\ubd81\uad6c\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_6d22eca3a2fa68a73d60fce62b1ed134.setIcon(div_icon_0476ef10f6fc455d2c28fce366441c85);
#
#
#             var circle_marker_9cbea3c3db804cf465f86e6f3876cebf = L.circleMarker(
#                 [37.581, 127.054],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fec35e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fec35e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 51, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9aa25e6801152f920971746e38660f52);
#
#
#         var popup_75e94ff8aaf0ec24ff48ada7346b59dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caf789053dbf0934f397e6f6e643c199 = $(`&lt;div id=&quot;html_caf789053dbf0934f397e6f6e643c199&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;동대문구&lt;/b&gt;&lt;br&gt;재개발(22-25): 16건&lt;br&gt;상위 25% 평당가: 4458만원&lt;/div&gt;`)[0];
#                 popup_75e94ff8aaf0ec24ff48ada7346b59dd.setContent(html_caf789053dbf0934f397e6f6e643c199);
#
#
#
#         circle_marker_9cbea3c3db804cf465f86e6f3876cebf.bindPopup(popup_75e94ff8aaf0ec24ff48ada7346b59dd)
#         ;
#
#
#
#
#             var marker_c70490ae96ed6510209481f64b6368ec = L.marker(
#                 [37.581, 127.054],
#                 {
# }
#             ).addTo(map_9aa25e6801152f920971746e38660f52);
#
#
#             var div_icon_1287aa52058212fd6f77eff16737f873 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; marg

# %%
import pandas as pd
import folium
import numpy as np
import matplotlib.colors as colors
import matplotlib.cm as cm

# 1. 법정동-자치구 매핑 사전 생성 (무시되는 동 방지용)
# 실거래가 데이터에서 동-구 관계를 추출하여 정비사업의 '동' 데이터를 '구'로 바꿈.
price_temp = pd.read_csv("서울시 부동산 실거래가 정보(2022~2025).csv", encoding="cp949", low_memory=False)
dong_to_gu = price_temp[['법정동명', '자치구명']].drop_duplicates().set_index('법정동명')['자치구명'].to_dict()

# 2. 정비사업 데이터 처리
df_plan = pd.read_csv("서울시 도시계획 정비사업 현황.csv", encoding="cp949")

# 소분류 결측값 찾았지만 재개발 건인지 알 수 없어 제외
df_plan[df_plan['소분류'].isnull()]
# 위치명 결측값 찾았지만 소분류가 재개발이 아니어서 제외
df_plan[df_plan['소분류'].isnull()]


df_plan["일자"] = df_plan["프로젝트코드"].str[8:16]
df_plan["구명"] = ""

for i in range(len(df_plan)):
    location_val = df_plan.loc[i, "위치명"]
    if pd.notnull(location_val) and str(location_val).strip() != "":
        loc_str = str(location_val).replace("서울특별시", "").replace("서울시", "").strip()
        
        # [Step 1]
        if "영등포동" in loc_str: target_gu = "영등포구"
        elif "노량진동" in loc_str: target_gu = "동작구"
        elif "신림동" in loc_str: target_gu = "관악구"
        elif "중곡동" in loc_str: target_gu = "광진구"
        elif any(x in loc_str for x in ["소공동", "산림동", "입정동", "태평로"]): target_gu = "중구"
        elif "전농동" in loc_str: target_gu = "동대문구"
        elif "금호동" in loc_str: target_gu = "성동구"
        elif "길음동" in loc_str: target_gu = "성북구"
        elif "한강로" in loc_str: target_gu = "용산구"
        elif "상계동" in loc_str: target_gu = "노원구"
        elif "명륜" in loc_str: target_gu = "종로구"
        elif "수색" in loc_str: target_gu = "은평구"
        else:
            # [Step 2] 동/로 이름 추출 시도
            find_idx = loc_str.find(" ")
            if find_idx == -1: find_idx = loc_str.find("동")
            if find_idx == -1: find_idx = loc_str.find("로")
            
            extracted_name = loc_str[:find_idx+1].strip() if find_idx != -1 else loc_str
            
            # [Step 3] 추출된 이름 자치구명인지 확인, 아니면 사전에서 검색
            if "구" in extracted_name and len(extracted_name) <= 4:
                target_gu = extracted_name
            else:
                # 사전(dong_to_gu)에서 동 이름을 찾아 구로 변환
                target_gu = dong_to_gu.get(extracted_name, "기타")
        
        df_plan.at[i, "구명"] = target_gu
    else:
        df_plan.at[i, "구명"] = "NULL"

# 2022년 이후 & '재개발' 필터링
redev_df = df_plan[(df_plan["일자"] >= "20220101") & (df_plan["소분류"].str.contains("재개발", na=False))].copy()
redev_counts = redev_df["구명"].value_counts().reset_index()
redev_counts.columns = ["자치구명", "재개발건수"]

# 3. 실거래가 데이터 처리 (2024년~2025년 데이터 중에서만 상위 25% 가격 추출)
# '계약일' 컬럼이 문자열 형태(YYYYMMDD)라고 가정할 때 필터링

# 실거래가 데이터에서 2024년 이후 데이터만 필터링
price_recent = price_temp[price_temp['계약일'] >= 20240101].copy()

# 단위면적당 금액 계산
price_recent['단위면적당금액'] = price_recent['물건금액(만원)'] / price_recent['건물면적(㎡)']

# 자치구별 상위 25% 가격 산출
price_stats = price_recent.groupby('자치구명')['단위면적당금액'].quantile(0.75).reset_index()
price_stats.columns = ['자치구명', '상위25%가격']

# 4. 데이터 병합
# (재개발 건수는 2022~2025 유지, 가격은 2024~2025 데이터로 매칭)
final_df = pd.merge(redev_counts, price_stats, on="자치구명")

# 5. 지도 시각화
seoul_geo = {
    '강남구': [37.495, 127.062], '강동구': [37.549, 127.146], '강북구': [37.642, 127.011],
    '강서구': [37.561, 126.825], '관악구': [37.465, 126.943], '광진구': [37.546, 127.085],
    '구로구': [37.494, 126.856], '금천구': [37.460, 126.900], '노원구': [37.652, 127.075],
    '도봉구': [37.669, 127.032], '동대문구': [37.581, 127.054], '동작구': [37.502, 126.951],
    '마포구': [37.559, 126.908], '서대문구': [37.577, 126.939], '서초구': [37.473, 127.031],
    '성동구': [37.551, 127.041], '성북구': [37.605, 127.017], '송파구': [37.505, 127.115],
    '양천구': [37.524, 126.855], '영등포구': [37.522, 126.910], '용산구': [37.530, 126.980],
    '은평구': [37.619, 126.927], '종로구': [37.594, 126.977], '중구': [37.560, 126.995], '중랑구': [37.597, 127.092]
}

m = folium.Map(location=[37.563, 126.986], zoom_start=11, tiles='cartodbpositron')
norm = colors.Normalize(vmin=final_df['상위25%가격'].min(), vmax=final_df['상위25%가격'].max())
cmap = cm.get_cmap('YlOrRd')

for _, row in final_df.iterrows():
    gu = row['자치구명']
    if gu in seoul_geo:
        color_hex = colors.to_hex(cmap(norm(row['상위25%가격'])))
        radius_val = row['재개발건수'] * 3 + 3 # 가독성을 위해 크기 보정
        
        folium.CircleMarker(
            location=seoul_geo[gu],
            radius=radius_val,
            color=color_hex,
            fill=True,
            fill_color=color_hex,
            fill_opacity=0.7,
            popup=f"<b>{gu}</b><br>재개발(22-25): {row['재개발건수']}건<br>상위 25% 평당가: {(row['상위25%가격']*3.3):.0f}만원",
        ).add_to(m)
        
        folium.Marker(
            location=seoul_geo[gu],
            icon=folium.DivIcon(html=f'<div style="font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;">{gu}</div>')
        ).add_to(m)

m.save('seoul_redevelopment_2022_2025_fixed.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c60fff712f582eec55f3b1308e1c9fc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c60fff712f582eec55f3b1308e1c9fc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c60fff712f582eec55f3b1308e1c9fc4 = L.map(
#                 &quot;map_c60fff712f582eec55f3b1308e1c9fc4&quot;,
#                 {
#                     center: [37.563, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b3045eb245e565c402c04443ba40c7a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b3045eb245e565c402c04443ba40c7a.addTo(map_c60fff712f582eec55f3b1308e1c9fc4);
#
#
#             var circle_marker_bbda2bb9a03bfe0f12c02d535aa95c20 = L.circleMarker(
#                 [37.605, 127.017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fedc7c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fedc7c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 60, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c60fff712f582eec55f3b1308e1c9fc4);
#
#
#         var popup_e3a18cec524df4d260e1eccd0366034a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f58d33d33d1737af9a67f33ff6a6c89 = $(`&lt;div id=&quot;html_7f58d33d33d1737af9a67f33ff6a6c89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;성북구&lt;/b&gt;&lt;br&gt;재개발(22-25): 19건&lt;br&gt;상위 25% 평당가: 3966만원&lt;/div&gt;`)[0];
#                 popup_e3a18cec524df4d260e1eccd0366034a.setContent(html_7f58d33d33d1737af9a67f33ff6a6c89);
#
#
#
#         circle_marker_bbda2bb9a03bfe0f12c02d535aa95c20.bindPopup(popup_e3a18cec524df4d260e1eccd0366034a)
#         ;
#
#
#
#
#             var marker_d5f29b9440007d8a831a494b1d4516dc = L.marker(
#                 [37.605, 127.017],
#                 {
# }
#             ).addTo(map_c60fff712f582eec55f3b1308e1c9fc4);
#
#
#             var div_icon_1282efa1a572bb477dc1a3f7ba5aafba = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;\&quot;\u003e\uc131\ubd81\uad6c\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_d5f29b9440007d8a831a494b1d4516dc.setIcon(div_icon_1282efa1a572bb477dc1a3f7ba5aafba);
#
#
#             var circle_marker_9b53b18720e7a3647c085f1f418a44b4 = L.circleMarker(
#                 [37.581, 127.054],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fec35e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fec35e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 51, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c60fff712f582eec55f3b1308e1c9fc4);
#
#
#         var popup_7701ae8387a311e1e27486e4ffb47bf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_911bc24e232e1029cc354abba02dfa72 = $(`&lt;div id=&quot;html_911bc24e232e1029cc354abba02dfa72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;동대문구&lt;/b&gt;&lt;br&gt;재개발(22-25): 16건&lt;br&gt;상위 25% 평당가: 4458만원&lt;/div&gt;`)[0];
#                 popup_7701ae8387a311e1e27486e4ffb47bf3.setContent(html_911bc24e232e1029cc354abba02dfa72);
#
#
#
#         circle_marker_9b53b18720e7a3647c085f1f418a44b4.bindPopup(popup_7701ae8387a311e1e27486e4ffb47bf3)
#         ;
#
#
#
#
#             var marker_f4225a3ebdb245c910a56fee1ecf5ed1 = L.marker(
#                 [37.581, 127.054],
#                 {
# }
#             ).addTo(map_c60fff712f582eec55f3b1308e1c9fc4);
#
#
#             var div_icon_57208e90b51d594a070c35fa2117e6d9 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; marg

# %% [markdown]
# ### 3. 2의 주장에 대한 근거(2011~2020 과거 데이터)

# %%
import pandas as pd
import folium
import numpy as np
import matplotlib.colors as colors
import matplotlib.cm as cm

# 1. 분할된 실거래가 데이터 통합
price_files = ['서울시 부동산 실거래가 정보 (9).csv', '서울시 부동산 실거래가 정보 (10).csv'
]

df_price_list = [] 
for f in price_files:
    temp_df = pd.read_csv(f, encoding='cp949', low_memory=False)
    df_price_list.append(temp_df)
    
df_price_total = pd.concat(df_price_list, ignore_index=True)
df_price_total['계약일_dt'] = pd.to_datetime(df_price_total['계약일'], format='%Y%m%d', errors='coerce')

dong_to_gu = df_price_total[['법정동명', '자치구명']].drop_duplicates().set_index('법정동명')['자치구명'].to_dict()

df_past_price = df_price_total[(df_price_total['계약일_dt'] >= '2011-01-01') & (df_price_total['계약일_dt'] < '2021-12-31')].copy()
df_past_price['단위면적당금액'] = df_past_price['물건금액(만원)'] / df_past_price['건물면적(㎡)']

price_stats = df_past_price.groupby('자치구명')['단위면적당금액'].quantile(0.75).reset_index()
price_stats.columns = ['자치구명', '과거상위25%가격']

# 2. 도시계획 정비사업 데이터 처리
df_plan = pd.read_csv("서울시 도시계획 정비사업 현황.csv", encoding="cp949")
df_plan["일자"] = df_plan["프로젝트코드"].str[8:16]
df_plan["구명"] = ""

for i in range(len(df_plan)):
    location_val = df_plan.loc[i, "위치명"]
    target_gu = "기타" 
    
    if pd.notnull(location_val) and str(location_val).strip() != "":
        loc_str = str(location_val).replace("서울특별시", "").replace("서울시", "").strip()
        
        if "영등포동" in loc_str: target_gu = "영등포구"
        elif "노량진동" in loc_str: target_gu = "동작구"
        elif "신림동" in loc_str: target_gu = "관악구"
        elif "중곡동" in loc_str: target_gu = "광진구"
        elif any(x in loc_str for x in ["소공동", "산림동", "입정동", "태평로"]): target_gu = "중구"
        elif "전농동" in loc_str: target_gu = "동대문구"
        elif "금호동" in loc_str: target_gu = "성동구"
        elif "길음동" in loc_str: target_gu = "성북구"
        elif "한강로" in loc_str: target_gu = "용산구"
        elif "상계동" in loc_str: target_gu = "노원구"
        elif "마포구" in loc_str: target_gu = "마포구"
        elif "명륜3가" in loc_str: target_gu = "종로구"
        elif "수색" in loc_str: target_gu = "은평구"
        else:
            find_idx = loc_str.find(" ")
            if find_idx == -1: find_idx = loc_str.find("동")
            if find_idx == -1: find_idx = loc_str.find("로")
            extracted_name = loc_str[:find_idx+1].strip() if find_idx != -1 else loc_str
            if "구" in extracted_name and len(extracted_name) <= 4:
                target_gu = extracted_name
            else:
                target_gu = dong_to_gu.get(extracted_name, "기타")
        df_plan.at[i, "구명"] = target_gu
    else:
        df_plan.at[i, "구명"] = "NULL"

redev_df = df_plan[(df_plan["일자"] >= "20110101") & (df_plan["일자"] <= "20201231") & (df_plan["소분류"].str.contains("재개발", na=False))].copy()
redev_counts = redev_df["구명"].value_counts().reset_index()
redev_counts.columns = ["자치구명", "재개발건수"]

# 3. 최종 데이터 병합
final_df = pd.merge(redev_counts, price_stats, on="자치구명")

# 4. 지도 시각화
seoul_geo = {
    '강남구': [37.495, 127.062], '강동구': [37.549, 127.146], '강북구': [37.642, 127.011],
    '강서구': [37.561, 126.825], '관악구': [37.465, 126.943], '광진구': [37.546, 127.085],
    '구로구': [37.494, 126.856], '금천구': [37.460, 126.900], '노원구': [37.652, 127.075],
    '도봉구': [37.669, 127.032], '동대문구': [37.581, 127.054], '동작구': [37.502, 126.951],
    '마포구': [37.559, 126.908], '서대문구': [37.577, 126.939], '서초구': [37.473, 127.031],
    '성동구': [37.551, 127.041], '성북구': [37.605, 127.017], '송파구': [37.505, 127.115],
    '양천구': [37.524, 126.855], '영등포구': [37.522, 126.910], '용산구': [37.530, 126.980],
    '은평구': [37.619, 126.927], '종로구': [37.594, 126.977], '중구': [37.560, 126.995], '중랑구': [37.597, 127.092]
}

m = folium.Map(location=[37.563, 126.986], zoom_start=11, tiles='cartodbpositron')
norm = colors.Normalize(vmin=final_df['과거상위25%가격'].min(), vmax=final_df['과거상위25%가격'].max())
colormap = cm.get_cmap('YlOrRd')

for _, row in final_df.iterrows():
    gu = row['자치구명']
    if gu in seoul_geo:
        color_hex = colors.to_hex(colormap(norm(row['과거상위25%가격'])))
        radius_val = np.sqrt(row['재개발건수']) * 3 + 5 
        
        folium.CircleMarker(
            location=seoul_geo[gu],
            radius=radius_val,
            color=color_hex,
            fill=True,
            fill_color=color_hex,
            fill_opacity=0.7,
            popup=f"<b>{gu}</b><br>과거 재개발: {row['재개발건수']}건<br>과거 상위 25% 가격: {row['과거상위25%가격']:.1f}만원/㎡",
        ).add_to(m)
        
        #텍스트 강조
        if gu in ['서대문구', '동대문구','성동구','송파구']:
            # 강조 스타일
            label_style = 'font-size: 13pt; font-weight: 900; color: #D32F2F; text-shadow: 1px 1px 2px white;'
        else:
            # 기본 스타일
            label_style = 'font-size: 5pt; font-weight: bold; color: black;'
            
        folium.Marker(
            location=seoul_geo[gu],
            icon=folium.DivIcon(html=f'<div style="{label_style} text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;">{gu}</div>')
        ).add_to(m)

m.save('seoul_past_combined_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bec29db31be28d7e9d5c1ca2ec18211 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bec29db31be28d7e9d5c1ca2ec18211&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bec29db31be28d7e9d5c1ca2ec18211 = L.map(
#                 &quot;map_4bec29db31be28d7e9d5c1ca2ec18211&quot;,
#                 {
#                     center: [37.563, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf1e9689d56c0410f7071c7b84c0bfa5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf1e9689d56c0410f7071c7b84c0bfa5.addTo(map_4bec29db31be28d7e9d5c1ca2ec18211);
#
#
#             var circle_marker_0682401af4f6e5295d090ce6b2e65cab = L.circleMarker(
#                 [37.594, 126.977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fee289&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fee289&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 35.886890422961, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4bec29db31be28d7e9d5c1ca2ec18211);
#
#
#         var popup_e1022ca0211b1cf2c8d3025c16d75786 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8925b887cbbe0ace7b2d1b24c8651d9 = $(`&lt;div id=&quot;html_c8925b887cbbe0ace7b2d1b24c8651d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;종로구&lt;/b&gt;&lt;br&gt;과거 재개발: 106건&lt;br&gt;과거 상위 25% 가격: 974.5만원/㎡&lt;/div&gt;`)[0];
#                 popup_e1022ca0211b1cf2c8d3025c16d75786.setContent(html_c8925b887cbbe0ace7b2d1b24c8651d9);
#
#
#
#         circle_marker_0682401af4f6e5295d090ce6b2e65cab.bindPopup(popup_e1022ca0211b1cf2c8d3025c16d75786)
#         ;
#
#
#
#
#             var marker_a880fa087990546f36c51eca2c9fc26c = L.marker(
#                 [37.594, 126.977],
#                 {
# }
#             ).addTo(map_4bec29db31be28d7e9d5c1ca2ec18211);
#
#
#             var div_icon_7bb9562f69ed33c83f6e043e894152a6 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 5pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;\&quot;\u003e\uc885\ub85c\uad6c\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_a880fa087990546f36c51eca2c9fc26c.setIcon(div_icon_7bb9562f69ed33c83f6e043e894152a6);
#
#
#             var circle_marker_ad22e0bf1866fd5e9c2db778f5dd0129 = L.circleMarker(
#                 [37.619, 126.927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff3ae&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff3ae&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 33.30194339616981, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4bec29db31be28d7e9d5c1ca2ec18211);
#
#
#         var popup_00cfe17b7055bf7864d014964b4e7339 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8300751e4afccf44cec403fd3afa2338 = $(`&lt;div id=&quot;html_8300751e4afccf44cec403fd3afa2338&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;은평구&lt;/b&gt;&lt;br&gt;과거 재개발: 89건&lt;br&gt;과거 상위 25% 가격: 812.4만원/㎡&lt;/div&gt;`)[0];
#                 popup_00cfe17b7055bf7864d014964b4e7339.setContent(html_8300751e4afccf44cec403fd3afa2338);
#
#
#
#         circle_marker_ad22e0bf1866fd5e9c2db778f5dd0129.bindPopup(popup_00cfe17b7055bf7864d014964b4e7339)
#         ;
#
#
#
#
#             var marker_21eebf9d50fc69e56c567939ca5d892a = L.marker(
#                 [37.619, 126.927],
#                 {
# }
#             ).addTo(map_4bec29db31be28d7e9d5c1ca2ec18211);
#
#
#             var div_icon_3230075a1ca01fcdaa901322905a0b2f = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 5pt; font-weight: bold; color: black; text-align: center; white-spa

# %%
import pandas as pd

def verify_only_imputed_data(df, n_samples=15):
    """
    이미 구 이름이 명시된 데이터는 제외하고, 
    로직을 통해 '보완'된 데이터들만 추출하여 검증
    """
    # 1. '위치명'에 '구'라는 단어가 없는 데이터 위주로 필터링 (보완 로직이 주로 작동한 대상)
    # 또는 '기타'로 분류되었다가 채워진 데이터를 타겟으로 합니다.
    mask = df['위치명'].str.contains('구 ') == False 
    imputed_candidates = df[mask]
    
    if len(imputed_candidates) < n_samples:
        imputed_candidates = df # 대상이 적으면 전체에서 추출
        
    print(f"--- 🔍 [결측치 보완 전용] 수기 검증 시작 (N={n_samples}) ---")
    print("구 정보가 누락되었던 주소가 로직에 의해 어떻게 보완되었는지 확인합니다.\n")
    
    sample = imputed_candidates.sample(n=n_samples, random_state=42)
    correct = 0
    
    for i, (idx, row) in enumerate(sample.iterrows()):
        raw_loc = row['위치명']
        mapped_gu = row['구명']
        
        print(f"[{i+1}/{n_samples}]")
        print(f"📍 원본 위치명: {raw_loc}  (<- '구' 정보가 불분명함)")
        print(f"✅ 보완된 구명: {mapped_gu}")
        
        # 실제 주소 대조 (예: 흑석동 -> 동작구)
        val = input(f"   이 주소는 '{mapped_gu}'에 속하는 게 맞나요? (y/n): ").strip().lower()
        if val == 'y':
            correct += 1
            
    accuracy = (correct / n_samples) * 100
    print("\n" + "="*50)
    print(f"📊 [보완 로직 검증 결과]")
    print(f"- 검증 대상: 결측치 보완 샘플 {n_samples}건")
    print(f"- 보완 성공: {correct}건")
    print(f"- 보완 정확도: {accuracy:.1f}% 수준 확인")
    print("="*50)

# 실행 (redev_df 기반)
verify_only_imputed_data(redev_df, n_samples=15)
# Out:
# --- 🔍 [결측치 보완 전용] 수기 검증 시작 (N=15) ---
# 구 정보가 누락되었던 주소가 로직에 의해 어떻게 보완되었는지 확인합니다.
#
# [1/15]
# 📍 원본 위치명: 이문동 149-8일원  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 동대문구
# [2/15]
# 📍 원본 위치명: 상계동 5-16번지 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 노원구
# [3/15]
# 📍 원본 위치명: 수색동 160-1 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [4/15]
# 📍 원본 위치명: 흑석동 90번지일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 동작구
# [5/15]
# 📍 원본 위치명: 흑석동 259-89번지 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 동작구
# [6/15]
# 📍 원본 위치명: 녹번동 4,19,53번지 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [7/15]
# 📍 원본 위치명: 영천동 69-20번지 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 서대문구
# [8/15]
# 📍 원본 위치명: 장위동 173-114 일원   (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 성북구
# [9/15]
# 📍 원본 위치명: 증산동 157-34 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [10/15]
# 📍 원본 위치명: 노량진동 232-19번지 일대   (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 동작구
# [11/15]
# 📍 원본 위치명: 수색동 115-5일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [12/15]
# 📍 원본 위치명: 서울시 노원구3.4동 109-43 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 기타
# [13/15]
# 📍 원본 위치명: 수색동 115번지 일원  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [14/15]
# 📍 원본 위치명: 수색동 17-28일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [15/15]
# 📍 원본 위치명: 노량진동 312-75번지 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 동작구
#
# ==================================================
# 📊 [보완 로직 검증 결과]
# - 검증 대상: 결측치 보완 샘플 15건
# - 보완 성공: 13건
# - 보완 정확도: 86.7% 수준 확인
# ==================================================
