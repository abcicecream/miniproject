# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ### 1. 재개발 횟수(원 크기)와 중앙값 거래가(색상도) 비교 분석

# %%
import pandas as pd
import folium
import numpy as np
import matplotlib.colors as colors
import matplotlib.cm as cm

# 1. 부동산 실거래가 데이터 처리 및 동-구 매핑 사전 생성
df_price = pd.read_csv('서울시 부동산 실거래가 정보(2022~2025).csv', encoding='cp949', low_memory=False)

# 동 이름 -> 구 이름 매핑 사전 (예: {"소공동": "중구", "공덕동": "마포구" ...})
# 실거래가 데이터에 법정동과 자치구 활용
dong_to_gu = df_price[['법정동명', '자치구명']].drop_duplicates().set_index('법정동명')['자치구명'].to_dict()

# 가격 데이터 중앙값 계산
df_price['물건금액(만원)'] = pd.to_numeric(df_price['물건금액(만원)'], errors='coerce')
price_stats = df_price.groupby('자치구명')['물건금액(만원)'].median().reset_index()
price_stats.columns = ['자치구명', '가격중앙값']

# 2. 정비사업 데이터 처리
df_plan = pd.read_csv("서울시 도시계획 정비사업 현황.csv", encoding="cp949")
df_plan["일자"] = df_plan["프로젝트코드"].str[8:16]
df_plan["구명"] = ""

for i in range(len(df_plan)):
    location_val = df_plan.loc[i, "위치명"]
    if pd.notnull(location_val) and str(location_val).strip() != "":
        loc_str = str(location_val).replace("서울특별시", "").replace("서울시", "").strip()
        
        #주소에서 '동'이나 '로' 이름을 추출하여 구명으로 변환, 구가 없는 결측치 데이터 보완
        find_idx = loc_str.find(" ")
        if find_idx == -1: find_idx = loc_str.find("동")
        if find_idx == -1: find_idx = loc_str.find("로")
        
        # 띄어쓰기나 '동/로' 앞의 글자 추출
        extracted_name = loc_str[:find_idx+1].strip() if find_idx != -1 else loc_str
        
        # 추출된 이름이 구라면 그대로 쓰고, 
        # 동 이름이라면 사전에서 구 이름을 찾아 사용.
        if "구" in extracted_name and len(extracted_name) <= 4:
            target_gu = extracted_name
        else:
            target_gu = dong_to_gu.get(extracted_name, "기타")
            
        df_plan.at[i, "구명"] = target_gu
    else:
        df_plan.at[i, "구명"] = "NULL"

# 2022년 이후 & 재개발 필터링, 소분류가 재개발이 아닌 행은 사용 안함.
redev_df = df_plan[(df_plan["일자"] >= "20220101") & (df_plan["소분류"].str.contains("재개발", na=False))].copy()

# 정상 집계
redev_counts = redev_df["구명"].value_counts().reset_index()
redev_counts.columns = ["자치구명", "재개발건수"]

# 3. 데이터 병합
final_map_df = pd.merge(redev_counts, price_stats, on="자치구명")

# 4. 지도 시각화
seoul_geo = {
    '강남구': [37.495, 127.062], '강동구': [37.549, 127.146], '강북구': [37.642, 127.011],
    '강서구': [37.561, 126.825], '관악구': [37.465, 126.943], '광진구': [37.546, 127.085],
    '구로구': [37.494, 126.856], '금천구': [37.460, 126.900], '노원구': [37.652, 127.075],
    '도봉구': [37.669, 127.032], '동대문구': [37.581, 127.054], '동작구': [37.502, 126.951],
    '마포구': [37.559, 126.908], '서대문구': [37.577, 126.939], '서초구': [37.473, 127.031],
    '성동구': [37.551, 127.041], '성북구': [37.605, 127.017], '송파구': [37.505, 127.115],
    '양천구': [37.524, 126.855], '영등포구': [37.522, 126.910], '용산구': [37.530, 126.980],
    '은평구': [37.619, 126.927], '종로구': [37.594, 126.977], '중구': [37.560, 126.995], '중랑구': [37.597, 127.092]
}

m = folium.Map(location=[37.563, 126.986], zoom_start=11, tiles='cartodbpositron')
norm = colors.Normalize(vmin=final_map_df['가격중앙값'].min(), vmax=final_map_df['가격중앙값'].max())
colormap = cm.get_cmap('YlOrRd')

for _, row in final_map_df.iterrows():
    gu = row['자치구명']
    if gu in seoul_geo:
        color_hex = colors.to_hex(colormap(norm(row['가격중앙값'])))
        radius_val = np.sqrt(row['재개발건수']) * 6 + 5 
        
        folium.CircleMarker(
            location=seoul_geo[gu],
            radius=radius_val,
            color=color_hex,
            fill=True,
            fill_color=color_hex,
            fill_opacity=0.7,
            popup=f"<b>{gu}</b><br>재개발: {row['재개발건수']}건<br>중앙값: {row['가격중앙값']:.0f}만원",
        ).add_to(m)
        
        folium.Marker(
            location=seoul_geo[gu],
            icon=folium.DivIcon(html=f'<div style="font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;">{gu}</div>')
        ).add_to(m)

m.save('seoul_redevelopment_complete_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00753deff277853fbe13c7a4673ffb5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00753deff277853fbe13c7a4673ffb5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00753deff277853fbe13c7a4673ffb5e = L.map(
#                 &quot;map_00753deff277853fbe13c7a4673ffb5e&quot;,
#                 {
#                     center: [37.563, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c04dbc16893335e99baae9f6f5600d78 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c04dbc16893335e99baae9f6f5600d78.addTo(map_00753deff277853fbe13c7a4673ffb5e);
#
#
#             var circle_marker_9ce65a026efe4d86861b7c87f0633f12 = L.circleMarker(
#                 [37.605, 127.017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fea546&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fea546&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 31.153393661244046, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_00753deff277853fbe13c7a4673ffb5e);
#
#
#         var popup_b6f31e4de9640efa2458f91375bfe20b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d83b10d4cb5e6d1bfc93d6ab74ec60a = $(`&lt;div id=&quot;html_4d83b10d4cb5e6d1bfc93d6ab74ec60a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;성북구&lt;/b&gt;&lt;br&gt;재개발: 19건&lt;br&gt;중앙값: 63000만원&lt;/div&gt;`)[0];
#                 popup_b6f31e4de9640efa2458f91375bfe20b.setContent(html_4d83b10d4cb5e6d1bfc93d6ab74ec60a);
#
#
#
#         circle_marker_9ce65a026efe4d86861b7c87f0633f12.bindPopup(popup_b6f31e4de9640efa2458f91375bfe20b)
#         ;
#
#
#
#
#             var marker_c0312d54f8d1d047b9338a27374dd98f = L.marker(
#                 [37.605, 127.017],
#                 {
# }
#             ).addTo(map_00753deff277853fbe13c7a4673ffb5e);
#
#
#             var div_icon_2614c5867f9cf8747810d8a61a78519c = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;\&quot;\u003e\uc131\ubd81\uad6c\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_c0312d54f8d1d047b9338a27374dd98f.setIcon(div_icon_2614c5867f9cf8747810d8a61a78519c);
#
#
#             var circle_marker_287823337bd7fc7444e79002882ef508 = L.circleMarker(
#                 [37.581, 127.054],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#feb953&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#feb953&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 29.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_00753deff277853fbe13c7a4673ffb5e);
#
#
#         var popup_cfe90ef962eeca3b2ecdd1bd5d1a55bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81d63d1401af8c6e78cf0e7b0ca4eb8c = $(`&lt;div id=&quot;html_81d63d1401af8c6e78cf0e7b0ca4eb8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;동대문구&lt;/b&gt;&lt;br&gt;재개발: 16건&lt;br&gt;중앙값: 57425만원&lt;/div&gt;`)[0];
#                 popup_cfe90ef962eeca3b2ecdd1bd5d1a55bc.setContent(html_81d63d1401af8c6e78cf0e7b0ca4eb8c);
#
#
#
#         circle_marker_287823337bd7fc7444e79002882ef508.bindPopup(popup_cfe90ef962eeca3b2ecdd1bd5d1a55bc)
#         ;
#
#
#
#
#             var marker_821222fcfcf14d720075daa151c32a8b = L.marker(
#                 [37.581, 127.054],
#                 {
# }
#             ).addTo(map_00753deff277853fbe13c7a4673ffb5e);
#
#
#             var div_icon_f145dc26d8bd8d09aa88dfbec2e0d9d3 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left:

# %% [markdown]
# ### 2. 재개발 횟수와 상위 25% 거래가 비교 분석

# %%
import pandas as pd
import folium
import numpy as np
import matplotlib.colors as colors
import matplotlib.cm as cm
import re

# 1. 데이터 로드
# 파일명이 실제 환경과 다를 수 있으니 확인 바랍니다.
price_temp = pd.read_csv("서울시 부동산 실거래가 정보(2022~2025).csv", encoding="cp949", low_memory=False)
df_plan = pd.read_csv("서울시 도시계획 정비사업 현황.csv", encoding="cp949")

# 2. 법정동-자치구 매핑 사전 생성 (동 이름만 있을 때를 대비)
# 중복된 동 이름(예: 신사동) 중 가장 빈도가 높은 구를 선택하여 매핑의 일관성 유지
mapping_df = price_temp[['법정동명', '자치구명']].value_counts().reset_index()
dong_to_gu = mapping_df.drop_duplicates('법정동명').set_index('법정동명')['자치구명'].to_dict()

# 서울시 자치구 리스트 (정확한 매칭용)
seoul_gu_list = [
    '강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', 
    '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', 
    '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'
]

# 3. 구명 추출 함수 (안정성 강화)
def get_gu_name(location_val):
    if pd.isnull(location_val) or str(location_val).strip() == "":
        return "NULL"
    
    loc_str = str(location_val).replace("서울특별시", "").replace("서울시", "").strip()
    
    # [Step 1] 문자열 내에 자치구 이름이 직접 포함되어 있는지 확인 (가장 확실한 방법)
    for gu in seoul_gu_list:
        if gu in loc_str:
            return gu
            
    # [Step 2] 주요 동/로 이름 예외 매핑
    special_cases = {
        "영등포동": "영등포구", "노량진동": "동작구", "신림동": "관악구", 
        "중곡동": "광진구", "전농동": "동대문구", "금호동": "성동구", 
        "길음동": "성북구", "상계동": "노원구", "수색": "은평구", "명륜": "종로구", "한강로": "용산구"
    }
    for key, val in special_cases.items():
        if key in loc_str:
            return val

    # [Step 3] 동 이름을 정규표현식으로 추출하여 사전 검색
    match = re.search(r'([가-힣]+(?:동|로|가))', loc_str)
    if match:
        dong_name = match.group(1)
        return dong_to_gu.get(dong_name, "기타")
        
    return "기타"

# 4. 정비사업 데이터 처리
df_plan["일자"] = df_plan["프로젝트코드"].str[8:16]
df_plan["구명"] = df_plan["위치명"].apply(get_gu_name)

# 2022년 이후 & '재개발' 필터링
redev_df = df_plan[(df_plan["일자"] >= "20220101") & (df_plan["소분류"].str.contains("재개발", na=False))].copy()
redev_counts = redev_df["구명"].value_counts().reset_index()
redev_counts.columns = ["자치구명", "재개발건수"]

# 5. 실거래가 데이터 처리 (2024년 이후 상위 25%)
price_recent = price_temp[price_temp['계약일'] >= 20240101].copy()
price_recent['단위면적당금액'] = price_recent['물건금액(만원)'] / price_recent['건물면적(㎡)']
price_stats = price_recent.groupby('자치구명')['단위면적당금액'].quantile(0.75).reset_index()
price_stats.columns = ['자치구명', '상위25%가격']

# 6. 데이터 병합 (how='left'를 사용하여 재개발 건수가 있는 구는 누락되지 않게 함)
final_df = pd.merge(redev_counts, price_stats, on="자치구명", how="left")
final_df = final_df[final_df['자치구명'] != "기타"].dropna(subset=['상위25%가격'])

# 7. 지도 시각화
seoul_geo = {
    '강남구': [37.495, 127.062], '강동구': [37.549, 127.146], '강북구': [37.642, 127.011],
    '강서구': [37.561, 126.825], '관악구': [37.465, 126.943], '광진구': [37.546, 127.085],
    '구로구': [37.494, 126.856], '금천구': [37.460, 126.900], '노원구': [37.652, 127.075],
    '도봉구': [37.669, 127.032], '동대문구': [37.581, 127.054], '동작구': [37.502, 126.951],
    '마포구': [37.559, 126.908], '서대문구': [37.577, 126.939], '서초구': [37.473, 127.031],
    '성동구': [37.551, 127.041], '성북구': [37.605, 127.017], '송파구': [37.505, 127.115],
    '양천구': [37.524, 126.855], '영등포구': [37.522, 126.910], '용산구': [37.530, 126.980],
    '은평구': [37.619, 126.927], '종로구': [37.594, 126.977], '중구': [37.560, 126.995], '중랑구': [37.597, 127.092]
}

m = folium.Map(location=[37.563, 126.986], zoom_start=11, tiles='cartodbpositron')
norm = colors.Normalize(vmin=final_df['상위25%가격'].min(), vmax=final_df['상위25%가격'].max())
cmap = cm.get_cmap('YlOrRd')

for _, row in final_df.iterrows():
    gu = row['자치구명']
    if gu in seoul_geo:
        color_hex = colors.to_hex(cmap(norm(row['상위25%가격'])))
        radius_val = row['재개발건수'] * 3 + 3 
        
        folium.CircleMarker(
            location=seoul_geo[gu],
            radius=radius_val,
            color=color_hex,
            fill=True,
            fill_color=color_hex,
            fill_opacity=0.7,
            popup=f"<b>{gu}</b><br>재개발(22-25): {int(row['재개발건수'])}건<br>상위 25% 평당가: {(row['상위25%가격']*3.3):.0f}만원",
        ).add_to(m)
        
        folium.Marker(
            location=seoul_geo[gu],
            icon=folium.DivIcon(html=f'<div style="font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;">{gu}</div>')
        ).add_to(m)

m.save('seoul_redevelopment_fixed_final.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5277f0b0aa8ba0d6c2bca20babe7130 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5277f0b0aa8ba0d6c2bca20babe7130&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5277f0b0aa8ba0d6c2bca20babe7130 = L.map(
#                 &quot;map_b5277f0b0aa8ba0d6c2bca20babe7130&quot;,
#                 {
#                     center: [37.563, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_074803254ac8655bcbe021d76789d06b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_074803254ac8655bcbe021d76789d06b.addTo(map_b5277f0b0aa8ba0d6c2bca20babe7130);
#
#
#             var circle_marker_96553b5879df70a60c6ecc21a9ae56f8 = L.circleMarker(
#                 [37.605, 127.017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fedc7c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fedc7c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 60, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b5277f0b0aa8ba0d6c2bca20babe7130);
#
#
#         var popup_e8424ffb5ff577d21d5ba46b28d50f96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92ffbedcf333c7686b5554345e2bc579 = $(`&lt;div id=&quot;html_92ffbedcf333c7686b5554345e2bc579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;성북구&lt;/b&gt;&lt;br&gt;재개발(22-25): 19건&lt;br&gt;상위 25% 평당가: 3966만원&lt;/div&gt;`)[0];
#                 popup_e8424ffb5ff577d21d5ba46b28d50f96.setContent(html_92ffbedcf333c7686b5554345e2bc579);
#
#
#
#         circle_marker_96553b5879df70a60c6ecc21a9ae56f8.bindPopup(popup_e8424ffb5ff577d21d5ba46b28d50f96)
#         ;
#
#
#
#
#             var marker_fb1a654139d47bc0c5e81a3550fa00a8 = L.marker(
#                 [37.605, 127.017],
#                 {
# }
#             ).addTo(map_b5277f0b0aa8ba0d6c2bca20babe7130);
#
#
#             var div_icon_49d17a7312822ef2cc687abf2fc51334 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;\&quot;\u003e\uc131\ubd81\uad6c\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_fb1a654139d47bc0c5e81a3550fa00a8.setIcon(div_icon_49d17a7312822ef2cc687abf2fc51334);
#
#
#             var circle_marker_af91c0b829a268a94edeeecddd59e2d6 = L.circleMarker(
#                 [37.581, 127.054],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fec35e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fec35e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 51, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b5277f0b0aa8ba0d6c2bca20babe7130);
#
#
#         var popup_0c03119ffedf45945a9ec2a915fbf78b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6029b6dac2c8bd73f26530fcf7e39af9 = $(`&lt;div id=&quot;html_6029b6dac2c8bd73f26530fcf7e39af9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;동대문구&lt;/b&gt;&lt;br&gt;재개발(22-25): 16건&lt;br&gt;상위 25% 평당가: 4458만원&lt;/div&gt;`)[0];
#                 popup_0c03119ffedf45945a9ec2a915fbf78b.setContent(html_6029b6dac2c8bd73f26530fcf7e39af9);
#
#
#
#         circle_marker_af91c0b829a268a94edeeecddd59e2d6.bindPopup(popup_0c03119ffedf45945a9ec2a915fbf78b)
#         ;
#
#
#
#
#             var marker_f8446473a8884ef6382dea510d85f59f = L.marker(
#                 [37.581, 127.054],
#                 {
# }
#             ).addTo(map_b5277f0b0aa8ba0d6c2bca20babe7130);
#
#
#             var div_icon_b03bf1f9cbb1f8850b0b52f00172ed63 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; marg

# %%
import pandas as pd
import folium
import numpy as np
import matplotlib.colors as colors
import matplotlib.cm as cm

# 1. 법정동-자치구 매핑 사전 생성 (무시되는 동 방지용)
# 실거래가 데이터에서 동-구 관계를 추출하여 정비사업의 '동' 데이터를 '구'로 바꿈.
price_temp = pd.read_csv("서울시 부동산 실거래가 정보(2022~2025).csv", encoding="cp949", low_memory=False)
dong_to_gu = price_temp[['법정동명', '자치구명']].drop_duplicates().set_index('법정동명')['자치구명'].to_dict()

# 2. 정비사업 데이터 처리
df_plan = pd.read_csv("서울시 도시계획 정비사업 현황.csv", encoding="cp949")

# 소분류 결측값 찾았지만 재개발 건인지 알 수 없어 제외
df_plan[df_plan['소분류'].isnull()]
# 위치명 결측값 찾았지만 소분류가 재개발이 아니어서 제외
df_plan[df_plan['소분류'].isnull()]


df_plan["일자"] = df_plan["프로젝트코드"].str[8:16]
df_plan["구명"] = ""

for i in range(len(df_plan)):
    location_val = df_plan.loc[i, "위치명"]
    if pd.notnull(location_val) and str(location_val).strip() != "":
        loc_str = str(location_val).replace("서울특별시", "").replace("서울시", "").strip()
        
        # [Step 1]
        if "영등포동" in loc_str: target_gu = "영등포구"
        elif "노량진동" in loc_str: target_gu = "동작구"
        elif "신림동" in loc_str: target_gu = "관악구"
        elif "중곡동" in loc_str: target_gu = "광진구"
        elif any(x in loc_str for x in ["소공동", "산림동", "입정동", "태평로"]): target_gu = "중구"
        elif "전농동" in loc_str: target_gu = "동대문구"
        elif "금호동" in loc_str: target_gu = "성동구"
        elif "길음동" in loc_str: target_gu = "성북구"
        elif "한강로" in loc_str: target_gu = "용산구"
        elif "상계동" in loc_str: target_gu = "노원구"
        elif "명륜" in loc_str: target_gu = "종로구"
        elif "수색" in loc_str: target_gu = "은평구"
        else:
            # [Step 2] 동/로 이름 추출 시도
            find_idx = loc_str.find(" ")
            if find_idx == -1: find_idx = loc_str.find("동")
            if find_idx == -1: find_idx = loc_str.find("로")
            
            extracted_name = loc_str[:find_idx+1].strip() if find_idx != -1 else loc_str
            
            # [Step 3] 추출된 이름 자치구명인지 확인, 아니면 사전에서 검색
            if "구" in extracted_name and len(extracted_name) <= 4:
                target_gu = extracted_name
            else:
                # 사전(dong_to_gu)에서 동 이름을 찾아 구로 변환
                target_gu = dong_to_gu.get(extracted_name, "기타")
        
        df_plan.at[i, "구명"] = target_gu
    else:
        df_plan.at[i, "구명"] = "NULL"

# 2022년 이후 & '재개발' 필터링
redev_df = df_plan[(df_plan["일자"] >= "20220101") & (df_plan["소분류"].str.contains("재개발", na=False))].copy()
redev_counts = redev_df["구명"].value_counts().reset_index()
redev_counts.columns = ["자치구명", "재개발건수"]

# 3. 실거래가 데이터 처리 (2024년~2025년 데이터 중에서만 상위 25% 가격 추출)
# '계약일' 컬럼이 문자열 형태(YYYYMMDD)라고 가정할 때 필터링

# 실거래가 데이터에서 2024년 이후 데이터만 필터링
price_recent = price_temp[price_temp['계약일'] >= 20240101].copy()

# 단위면적당 금액 계산
price_recent['단위면적당금액'] = price_recent['물건금액(만원)'] / price_recent['건물면적(㎡)']

# 자치구별 상위 25% 가격 산출
price_stats = price_recent.groupby('자치구명')['단위면적당금액'].quantile(0.75).reset_index()
price_stats.columns = ['자치구명', '상위25%가격']

# 4. 데이터 병합
# (재개발 건수는 2022~2025 유지, 가격은 2024~2025 데이터로 매칭)
final_df = pd.merge(redev_counts, price_stats, on="자치구명")

# 5. 지도 시각화
seoul_geo = {
    '강남구': [37.495, 127.062], '강동구': [37.549, 127.146], '강북구': [37.642, 127.011],
    '강서구': [37.561, 126.825], '관악구': [37.465, 126.943], '광진구': [37.546, 127.085],
    '구로구': [37.494, 126.856], '금천구': [37.460, 126.900], '노원구': [37.652, 127.075],
    '도봉구': [37.669, 127.032], '동대문구': [37.581, 127.054], '동작구': [37.502, 126.951],
    '마포구': [37.559, 126.908], '서대문구': [37.577, 126.939], '서초구': [37.473, 127.031],
    '성동구': [37.551, 127.041], '성북구': [37.605, 127.017], '송파구': [37.505, 127.115],
    '양천구': [37.524, 126.855], '영등포구': [37.522, 126.910], '용산구': [37.530, 126.980],
    '은평구': [37.619, 126.927], '종로구': [37.594, 126.977], '중구': [37.560, 126.995], '중랑구': [37.597, 127.092]
}

m = folium.Map(location=[37.563, 126.986], zoom_start=11, tiles='cartodbpositron')
norm = colors.Normalize(vmin=final_df['상위25%가격'].min(), vmax=final_df['상위25%가격'].max())
cmap = cm.get_cmap('YlOrRd')

for _, row in final_df.iterrows():
    gu = row['자치구명']
    if gu in seoul_geo:
        color_hex = colors.to_hex(cmap(norm(row['상위25%가격'])))
        radius_val = row['재개발건수'] * 3 + 3 # 가독성을 위해 크기 보정
        
        folium.CircleMarker(
            location=seoul_geo[gu],
            radius=radius_val,
            color=color_hex,
            fill=True,
            fill_color=color_hex,
            fill_opacity=0.7,
            popup=f"<b>{gu}</b><br>재개발(22-25): {row['재개발건수']}건<br>상위 25% 평당가: {(row['상위25%가격']*3.3):.0f}만원",
        ).add_to(m)
        
        folium.Marker(
            location=seoul_geo[gu],
            icon=folium.DivIcon(html=f'<div style="font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;">{gu}</div>')
        ).add_to(m)

m.save('seoul_redevelopment_2022_2025_fixed.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68d4bab1060b92c1e6c4db5a50c75518 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68d4bab1060b92c1e6c4db5a50c75518&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68d4bab1060b92c1e6c4db5a50c75518 = L.map(
#                 &quot;map_68d4bab1060b92c1e6c4db5a50c75518&quot;,
#                 {
#                     center: [37.563, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebe0f3c6d0f8a1639052c92bb825f9a9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebe0f3c6d0f8a1639052c92bb825f9a9.addTo(map_68d4bab1060b92c1e6c4db5a50c75518);
#
#
#             var circle_marker_b6ffc78dbe0279f216f7568c314d13f3 = L.circleMarker(
#                 [37.605, 127.017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fedc7c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fedc7c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 60, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_68d4bab1060b92c1e6c4db5a50c75518);
#
#
#         var popup_183ff788a52a7ddaa78855d0a0cfd7d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9583d75379e3c9af09170e5a108916d4 = $(`&lt;div id=&quot;html_9583d75379e3c9af09170e5a108916d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;성북구&lt;/b&gt;&lt;br&gt;재개발(22-25): 19건&lt;br&gt;상위 25% 평당가: 3966만원&lt;/div&gt;`)[0];
#                 popup_183ff788a52a7ddaa78855d0a0cfd7d7.setContent(html_9583d75379e3c9af09170e5a108916d4);
#
#
#
#         circle_marker_b6ffc78dbe0279f216f7568c314d13f3.bindPopup(popup_183ff788a52a7ddaa78855d0a0cfd7d7)
#         ;
#
#
#
#
#             var marker_35152500e17a28afe15d6204d4141d61 = L.marker(
#                 [37.605, 127.017],
#                 {
# }
#             ).addTo(map_68d4bab1060b92c1e6c4db5a50c75518);
#
#
#             var div_icon_428c89355bf95c036f7d53548ad66784 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;\&quot;\u003e\uc131\ubd81\uad6c\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_35152500e17a28afe15d6204d4141d61.setIcon(div_icon_428c89355bf95c036f7d53548ad66784);
#
#
#             var circle_marker_c0818783b8d96573d8811a603cb333ce = L.circleMarker(
#                 [37.581, 127.054],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fec35e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fec35e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 51, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_68d4bab1060b92c1e6c4db5a50c75518);
#
#
#         var popup_209a548270ceb093c29c57caa9305b92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a2fce7f8e39e7f7692a24c535bcce95 = $(`&lt;div id=&quot;html_9a2fce7f8e39e7f7692a24c535bcce95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;동대문구&lt;/b&gt;&lt;br&gt;재개발(22-25): 16건&lt;br&gt;상위 25% 평당가: 4458만원&lt;/div&gt;`)[0];
#                 popup_209a548270ceb093c29c57caa9305b92.setContent(html_9a2fce7f8e39e7f7692a24c535bcce95);
#
#
#
#         circle_marker_c0818783b8d96573d8811a603cb333ce.bindPopup(popup_209a548270ceb093c29c57caa9305b92)
#         ;
#
#
#
#
#             var marker_8f6f886d981717d59e01e65852e1a3cf = L.marker(
#                 [37.581, 127.054],
#                 {
# }
#             ).addTo(map_68d4bab1060b92c1e6c4db5a50c75518);
#
#
#             var div_icon_5a289d91dd7e67df137cc7d8b3e09cc7 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; marg

# %% [markdown]
# ### 3. 2의 주장에 대한 근거(2011~2020 과거 데이터)

# %%
import pandas as pd
import folium
import numpy as np
import matplotlib.colors as colors
import matplotlib.cm as cm

# 1. 분할된 실거래가 데이터 통합
price_files = ['서울시 부동산 실거래가 정보 (9).csv', '서울시 부동산 실거래가 정보 (10).csv'
]

df_price_list = [] 
for f in price_files:
    temp_df = pd.read_csv(f, encoding='cp949', low_memory=False)
    df_price_list.append(temp_df)
    
df_price_total = pd.concat(df_price_list, ignore_index=True)
df_price_total['계약일_dt'] = pd.to_datetime(df_price_total['계약일'], format='%Y%m%d', errors='coerce')

dong_to_gu = df_price_total[['법정동명', '자치구명']].drop_duplicates().set_index('법정동명')['자치구명'].to_dict()

df_past_price = df_price_total[(df_price_total['계약일_dt'] >= '2011-01-01') & (df_price_total['계약일_dt'] < '2021-12-31')].copy()
df_past_price['단위면적당금액'] = df_past_price['물건금액(만원)'] / df_past_price['건물면적(㎡)']

price_stats = df_past_price.groupby('자치구명')['단위면적당금액'].quantile(0.75).reset_index()
price_stats.columns = ['자치구명', '과거상위25%가격']

# 2. 도시계획 정비사업 데이터 처리
df_plan = pd.read_csv("서울시 도시계획 정비사업 현황.csv", encoding="cp949")
df_plan["일자"] = df_plan["프로젝트코드"].str[8:16]
df_plan["구명"] = ""

for i in range(len(df_plan)):
    location_val = df_plan.loc[i, "위치명"]
    target_gu = "기타" 
    
    if pd.notnull(location_val) and str(location_val).strip() != "":
        loc_str = str(location_val).replace("서울특별시", "").replace("서울시", "").strip()
        
        if "영등포동" in loc_str: target_gu = "영등포구"
        elif "노량진동" in loc_str: target_gu = "동작구"
        elif "신림동" in loc_str: target_gu = "관악구"
        elif "중곡동" in loc_str: target_gu = "광진구"
        elif any(x in loc_str for x in ["소공동", "산림동", "입정동", "태평로"]): target_gu = "중구"
        elif "전농동" in loc_str: target_gu = "동대문구"
        elif "금호동" in loc_str: target_gu = "성동구"
        elif "길음동" in loc_str: target_gu = "성북구"
        elif "한강로" in loc_str: target_gu = "용산구"
        elif "상계동" in loc_str: target_gu = "노원구"
        elif "마포구" in loc_str: target_gu = "마포구"
        elif "명륜3가" in loc_str: target_gu = "종로구"
        elif "수색" in loc_str: target_gu = "은평구"
        else:
            find_idx = loc_str.find(" ")
            if find_idx == -1: find_idx = loc_str.find("동")
            if find_idx == -1: find_idx = loc_str.find("로")
            extracted_name = loc_str[:find_idx+1].strip() if find_idx != -1 else loc_str
            if "구" in extracted_name and len(extracted_name) <= 4:
                target_gu = extracted_name
            else:
                target_gu = dong_to_gu.get(extracted_name, "기타")
        df_plan.at[i, "구명"] = target_gu
    else:
        df_plan.at[i, "구명"] = "NULL"

redev_df = df_plan[(df_plan["일자"] >= "20110101") & (df_plan["일자"] <= "20201231") & (df_plan["소분류"].str.contains("재개발", na=False))].copy()
redev_counts = redev_df["구명"].value_counts().reset_index()
redev_counts.columns = ["자치구명", "재개발건수"]

# 3. 최종 데이터 병합
final_df = pd.merge(redev_counts, price_stats, on="자치구명")

# 4. 지도 시각화
seoul_geo = {
    '강남구': [37.495, 127.062], '강동구': [37.549, 127.146], '강북구': [37.642, 127.011],
    '강서구': [37.561, 126.825], '관악구': [37.465, 126.943], '광진구': [37.546, 127.085],
    '구로구': [37.494, 126.856], '금천구': [37.460, 126.900], '노원구': [37.652, 127.075],
    '도봉구': [37.669, 127.032], '동대문구': [37.581, 127.054], '동작구': [37.502, 126.951],
    '마포구': [37.559, 126.908], '서대문구': [37.577, 126.939], '서초구': [37.473, 127.031],
    '성동구': [37.551, 127.041], '성북구': [37.605, 127.017], '송파구': [37.505, 127.115],
    '양천구': [37.524, 126.855], '영등포구': [37.522, 126.910], '용산구': [37.530, 126.980],
    '은평구': [37.619, 126.927], '종로구': [37.594, 126.977], '중구': [37.560, 126.995], '중랑구': [37.597, 127.092]
}

m = folium.Map(location=[37.563, 126.986], zoom_start=11, tiles='cartodbpositron')
norm = colors.Normalize(vmin=final_df['과거상위25%가격'].min(), vmax=final_df['과거상위25%가격'].max())
colormap = cm.get_cmap('YlOrRd')

for _, row in final_df.iterrows():
    gu = row['자치구명']
    if gu in seoul_geo:
        color_hex = colors.to_hex(colormap(norm(row['과거상위25%가격'])))
        radius_val = np.sqrt(row['재개발건수']) * 3 + 5 
        
        folium.CircleMarker(
            location=seoul_geo[gu],
            radius=radius_val,
            color=color_hex,
            fill=True,
            fill_color=color_hex,
            fill_opacity=0.7,
            popup=f"<b>{gu}</b><br>과거 재개발: {row['재개발건수']}건<br>과거 상위 25% 가격: {row['과거상위25%가격']:.1f}만원/㎡",
        ).add_to(m)
        
        #텍스트 강조
        if gu in ['서대문구', '동대문구','성동구','송파구']:
            # 강조 스타일
            label_style = 'font-size: 13pt; font-weight: 900; color: #D32F2F; text-shadow: 1px 1px 2px white;'
        else:
            # 기본 스타일
            label_style = 'font-size: 5pt; font-weight: bold; color: black;'
            
        folium.Marker(
            location=seoul_geo[gu],
            icon=folium.DivIcon(html=f'<div style="{label_style} text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;">{gu}</div>')
        ).add_to(m)

m.save('seoul_past_combined_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c19ceb39fb7d569f577025d68f7fdfc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c19ceb39fb7d569f577025d68f7fdfc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c19ceb39fb7d569f577025d68f7fdfc8 = L.map(
#                 &quot;map_c19ceb39fb7d569f577025d68f7fdfc8&quot;,
#                 {
#                     center: [37.563, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_404841ba39297528411ff09fefde6246 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_404841ba39297528411ff09fefde6246.addTo(map_c19ceb39fb7d569f577025d68f7fdfc8);
#
#
#             var circle_marker_a955b7e1c6c820e7a7812a70413107f0 = L.circleMarker(
#                 [37.594, 126.977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fee289&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fee289&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 35.886890422961, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c19ceb39fb7d569f577025d68f7fdfc8);
#
#
#         var popup_f527be71fb379f904449989e2d085f95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78177c1ac2fede85df29dd4bd247c097 = $(`&lt;div id=&quot;html_78177c1ac2fede85df29dd4bd247c097&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;종로구&lt;/b&gt;&lt;br&gt;과거 재개발: 106건&lt;br&gt;과거 상위 25% 가격: 974.5만원/㎡&lt;/div&gt;`)[0];
#                 popup_f527be71fb379f904449989e2d085f95.setContent(html_78177c1ac2fede85df29dd4bd247c097);
#
#
#
#         circle_marker_a955b7e1c6c820e7a7812a70413107f0.bindPopup(popup_f527be71fb379f904449989e2d085f95)
#         ;
#
#
#
#
#             var marker_f34e0f4deafdb1a450e79035a1895a6e = L.marker(
#                 [37.594, 126.977],
#                 {
# }
#             ).addTo(map_c19ceb39fb7d569f577025d68f7fdfc8);
#
#
#             var div_icon_afa7a955a0ff3709ab28e0b3d71c9887 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 5pt; font-weight: bold; color: black; text-align: center; white-space: nowrap; width: 100px; margin-left: -50px;\&quot;\u003e\uc885\ub85c\uad6c\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_f34e0f4deafdb1a450e79035a1895a6e.setIcon(div_icon_afa7a955a0ff3709ab28e0b3d71c9887);
#
#
#             var circle_marker_31ab04863f64473d7f7432702bf46feb = L.circleMarker(
#                 [37.619, 126.927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff3ae&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff3ae&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 33.30194339616981, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c19ceb39fb7d569f577025d68f7fdfc8);
#
#
#         var popup_a2a36b5c688ad4f0d80b00cd969f46bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b2164fe764f6bd702c70a34e60eb636 = $(`&lt;div id=&quot;html_6b2164fe764f6bd702c70a34e60eb636&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;은평구&lt;/b&gt;&lt;br&gt;과거 재개발: 89건&lt;br&gt;과거 상위 25% 가격: 812.4만원/㎡&lt;/div&gt;`)[0];
#                 popup_a2a36b5c688ad4f0d80b00cd969f46bc.setContent(html_6b2164fe764f6bd702c70a34e60eb636);
#
#
#
#         circle_marker_31ab04863f64473d7f7432702bf46feb.bindPopup(popup_a2a36b5c688ad4f0d80b00cd969f46bc)
#         ;
#
#
#
#
#             var marker_18f6eae24d0243bf364a6079afe265ca = L.marker(
#                 [37.619, 126.927],
#                 {
# }
#             ).addTo(map_c19ceb39fb7d569f577025d68f7fdfc8);
#
#
#             var div_icon_07d0c8464c9f31119e6b9310d0a5fa58 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 5pt; font-weight: bold; color: black; text-align: center; white-spa

# %%
import pandas as pd

def verify_only_imputed_data(df, n_samples=15):
    """
    이미 구 이름이 명시된 데이터는 제외하고, 
    로직을 통해 '보완'된 데이터들만 추출하여 검증
    """
    # 1. '위치명'에 '구'라는 단어가 없는 데이터 위주로 필터링 (보완 로직이 주로 작동한 대상)
    # 또는 '기타'로 분류되었다가 채워진 데이터를 타겟으로 합니다.
    mask = df['위치명'].str.contains('구 ') == False 
    imputed_candidates = df[mask]
    
    if len(imputed_candidates) < n_samples:
        imputed_candidates = df # 대상이 적으면 전체에서 추출
        
    print(f"--- 🔍 [결측치 보완 전용] 수기 검증 시작 (N={n_samples}) ---")
    print("구 정보가 누락되었던 주소가 로직에 의해 어떻게 보완되었는지 확인합니다.\n")
    
    sample = imputed_candidates.sample(n=n_samples, random_state=42)
    correct = 0
    
    for i, (idx, row) in enumerate(sample.iterrows()):
        raw_loc = row['위치명']
        mapped_gu = row['구명']
        
        print(f"[{i+1}/{n_samples}]")
        print(f"📍 원본 위치명: {raw_loc}  (<- '구' 정보가 불분명함)")
        print(f"✅ 보완된 구명: {mapped_gu}")
        
        # 실제 주소 대조 (예: 흑석동 -> 동작구)
        val = input(f"   이 주소는 '{mapped_gu}'에 속하는 게 맞나요? (y/n): ").strip().lower()
        if val == 'y':
            correct += 1
            
    accuracy = (correct / n_samples) * 100
    print("\n" + "="*50)
    print(f"📊 [보완 로직 검증 결과]")
    print(f"- 검증 대상: 결측치 보완 샘플 {n_samples}건")
    print(f"- 보완 성공: {correct}건")
    print(f"- 보완 정확도: {accuracy:.1f}% 수준 확인")
    print("="*50)

# 실행 (redev_df 기반)
verify_only_imputed_data(redev_df, n_samples=15)
# Out:
# --- 🔍 [결측치 보완 전용] 수기 검증 시작 (N=15) ---
# 구 정보가 누락되었던 주소가 로직에 의해 어떻게 보완되었는지 확인합니다.
#
# [1/15]
# 📍 원본 위치명: 이문동 149-8일원  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 동대문구
# [2/15]
# 📍 원본 위치명: 상계동 5-16번지 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 노원구
# [3/15]
# 📍 원본 위치명: 수색동 160-1 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [4/15]
# 📍 원본 위치명: 흑석동 90번지일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 동작구
# [5/15]
# 📍 원본 위치명: 흑석동 259-89번지 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 동작구
# [6/15]
# 📍 원본 위치명: 녹번동 4,19,53번지 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [7/15]
# 📍 원본 위치명: 영천동 69-20번지 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 서대문구
# [8/15]
# 📍 원본 위치명: 장위동 173-114 일원   (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 성북구
# [9/15]
# 📍 원본 위치명: 증산동 157-34 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [10/15]
# 📍 원본 위치명: 노량진동 232-19번지 일대   (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 동작구
# [11/15]
# 📍 원본 위치명: 수색동 115-5일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [12/15]
# 📍 원본 위치명: 서울시 노원구3.4동 109-43 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 기타
# [13/15]
# 📍 원본 위치명: 수색동 115번지 일원  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [14/15]
# 📍 원본 위치명: 수색동 17-28일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 은평구
# [15/15]
# 📍 원본 위치명: 노량진동 312-75번지 일대  (<- '구' 정보가 불분명함)
# ✅ 보완된 구명: 동작구
#
# ==================================================
# 📊 [보완 로직 검증 결과]
# - 검증 대상: 결측치 보완 샘플 15건
# - 보완 성공: 13건
# - 보완 정확도: 86.7% 수준 확인
# ==================================================

# %%
import time
import pandas as pd

# 성능 테스트를 위한 데이터 복사
df_test_loc = df_plan.copy()
df_test_at = df_plan.copy()

# ---------------------------------------------------------
# 1. .loc 사용 시 시간 측정
# ---------------------------------------------------------
start_loc = time.time()
for i in range(len(df_test_loc)):
    # 기존 코드의 로직을 그대로 사용 (loc 사용)
    location_val = df_test_loc.loc[i, "위치명"]
    # ... (중간 필터링 로직은 동일하므로 생략하거나 target_gu 변수 생성)
    target_gu = "테스트구" 
    df_test_loc.loc[i, "구명"] = target_gu
end_loc = time.time()

time_loc = end_loc - start_loc
print(f"1. .loc 사용 시 소요 시간: {time_loc:.4f} 초")

# ---------------------------------------------------------
# 2. .at 사용 시 시간 측정
# ---------------------------------------------------------
start_at = time.time()
for i in range(len(df_test_at)):
    # 최적화된 .at 사용
    location_val = df_test_at.at[i, "위치명"]
    target_gu = "테스트구" 
    df_test_at.at[i, "구명"] = target_gu
end_at = time.time()

time_at = end_at - start_at
print(f"2. .at 사용 시 소요 시간: {time_at:.4f} 초")

# ---------------------------------------------------------
# 3. 결과 분석 및 개선율 계산
# ---------------------------------------------------------
improvement = (time_loc - time_at) / time_loc * 100
print("-" * 30)
print(f"결과: .at이 .loc보다 {time_loc/time_at:.2f}배 더 빠릅니다.")
print(f"전처리 시간 단축률: {improvement:.2f}%")
# Out:
# 1. .loc 사용 시 소요 시간: 1.1115 초
# 2. .at 사용 시 소요 시간: 0.1410 초
# ------------------------------
# 결과: .at이 .loc보다 7.88배 더 빠릅니다.
# 전처리 시간 단축률: 87.32%
